# %%
#Imports
from pyrh import Robinhood
import dotenv
dotenv.load_dotenv()
import os
import numpy as np
import sched, time
import importlib.util
import StockPredictorModule as spm
import DecisionTree as dt

def RHlogin():
    USERNAME = os.getenv("RH_USERNAME")
    PASSWORD = os.getenv("RH_PASSWORD")

    rh = Robinhood(username=USERNAME, password=PASSWORD)
    rh.login()
    return rh

    
def inspect_historicals(rh):
    print("Getting Historical Quotes")
     # Get 5 minute graph data for Ford stock
    historical_quotes = rh.get_historical_quotes("TWTR", "5minute", "day")
    print(historical_quotes['results'][0]["historicals"])


def plot_future_predictions(stock:str):
    stock_predict = spm.Stock_Predict(stock)
    stock_predict.plot_future_predictions()

# %%
if __name__ == "__main__":
    ###GET CSV FILES TO TRAIN DECISION TREE###
    csvdata = dt.CSV_Maker()
    stocklist = ["AAPL", "MSFT", "SBUX", "SNAP", "F"]    #List of Stocks for training
    csvdata.add_csv_data(stocklist)                      #Adds row of data in the csv based on every index
    csvdata.read_csv()
    csvdata.encode_csv()                                     #Shows the row of data encoded since DT cant read strings
    
    success = np.array([1])
    fail = np.array([0])
    s = sched.scheduler(time.time, time.sleep)
    
    tree = dt.StockDecisionTree()
    
    def should_buy(stock:str):
        buy = tree.make_prediction(csvdata.return_row(stock))
        return buy
    
    def visualize_predictions(stocklist:[]):
        for i in range(len(stocklist)):
            plot_future_predictions(stocklist[i])
    
    def get_instrument(stock):
        instrument = rh.instruments("")[0]
        return instrument
    
    
    def run_script():
        rh = RHlogin()
#     inspect_historicals(rh)
        instrument = get_instrument("F")
        buy = should_buy("F")
        traded = False
    
        if (buy == succcess):
            rh.place_buy_order(instrument, 1)
            traded = True
    
        if (buy == fail and traded == True):
            rh.place_sell_order(instrument,1)
    
    s.enter(100, 1, run_script, (s,))
    s.run()
# Out:
# Epoch 1/50
# 6/6 [==============================] - 6s 416ms/step - loss: 0.0106 - val_loss: 0.0149
# Epoch 2/50
# 6/6 [==============================] - 1s 117ms/step - loss: 0.0023 - val_loss: 0.0388
# Epoch 3/50
# 6/6 [==============================] - 1s 113ms/step - loss: 0.0018 - val_loss: 0.0224
# Epoch 4/50
# 6/6 [==============================] - 1s 115ms/step - loss: 8.6308e-04 - val_loss: 0.0170
# Epoch 5/50
# 6/6 [==============================] - 1s 117ms/step - loss: 5.7691e-04 - val_loss: 0.0191
# Epoch 6/50
# 6/6 [==============================] - 1s 113ms/step - loss: 4.9480e-04 - val_loss: 0.0115
# Epoch 7/50
# 6/6 [==============================] - 1s 115ms/step - loss: 2.6385e-04 - val_loss: 0.0103
# Epoch 8/50
# 6/6 [==============================] - 1s 113ms/step - loss: 1.6754e-04 - val_loss: 0.0104
# Epoch 9/50
# 6/6 [==============================] - 1s 116ms/step - loss: 1.7575e-04 - val_loss: 0.0101
# Epoch 10/50
# 6/6 [==============================] - 1s 115ms/step - loss: 2.5990e-04 - val_loss: 0.0101
# Epoch 11/50
# 6/6 [==============================] - 1s 114ms/step - loss: 1.9970e-04 - val_loss: 0.0101
# Epoch 12/50
# 6/6 [==============================] - 1s 115ms/step - loss: 1.8579e-04 - val_loss: 0.0097
# Epoch 13/50
# 6/6 [==============================] - 1s 115ms/step - loss: 1.5836e-04 - val_loss: 0.0099
# Epoch 43/50
# 6/6 [==============================] - 1s 118ms/step - loss: 1.0899e-04 - val_loss: 0.0084
# Epoch 44/50
# 6/6 [==============================] - 1s 119ms/step - loss: 1.0921e-04 - val_loss: 0.0079
# Epoch 45/50
# 6/6 [==============================] - 1s 117ms/step - loss: 1.2510e-04 - val_loss: 0.0080
# Epoch 46/50
# 6/6 [==============================] - 1s 119ms/step - loss: 1.2464e-04 - val_loss: 0.0081
# Epoch 47/50
# 6/6 [==============================] - 1s 121ms/step - loss: 1.0601e-04 - val_loss: 0.0082
# Epoch 48/50
# 6/6 [==============================] - 1s 118ms/step - loss: 1.2715e-04 - val_loss: 0.0077
# Epoch 49/50
# 6/6 [==============================] - 1s 118ms/step - loss: 1.0880e-04 - val_loss: 0.0079
# Epoch 50/50
# 6/6 [==============================] - 1s 119ms/step - loss: 9.5284e-05 - val_loss: 0.0077
# 1 day output [[0.11071999]]
# 2 day output [[0.11106078]]
# 3 day output [[0.11145876]]
# 4 day output [[0.11193068]]
# 5 day output [[0.11247732]]
# 6 day output [[0.11309043]]
# 7 day output [[0.11375782]]
# 8 day output [[0.1144665]]
# 9 day output [[0.11520463]]
# 10 day output [[0.11596227]]
# 11 day output [[0.11673176]]
# 12 day output [[0.11750749]]
# 13 day output [[0.11828565]]
# 14 day output [[0.11906376]]
# 15 day output [[0.11984049]]
# 16 day output [[0.12061509]]
# 17 day output [[0.12138739]]
# 18 day output [[0.12215738]]
# 19 day output [[0.12292518]]
# 20 day output [[0.12369101]]
# 21 day output [[0.12445509]]
# 22 day output [[0.12521753]]
# 23 day output [[0.12597844]]
# 24 day output [[0.12673795]]
# 25 day output [[0.12749603]]
# 26 day output [[0.12825276]]
# 27 day output [[0.12900811]]
# 28 day output [[0.12976207]]
# 29 day output [[0.13051464]]
# AAPL 1 0 1 1
# Epoch 1/50
# 6/6 [==============================] - 5s 276ms/step - loss: 0.0066 - val_loss: 0.0348
# Epoch 2/50
# 6/6 [==============================] - 1s 115ms/step - loss: 0.0016 - val_loss: 0.1002
# Epoch 3/50
# 6/6 [==============================] - 1s 117ms/step - loss: 9.8044e-04 - val_loss: 0.0395
# Epoch 4/50
# 6/6 [==============================] - 1s 123ms/step - loss: 6.8209e-04 - val_loss: 0.0363
# Epoch 5/50
# 6/6 [==============================] - 1s 122ms/step - loss: 3.3359e-04 - val_loss: 0.0140
# Epoch 6/50
# 6/6 [==============================] - 1s 120ms/step - loss: 1.4381e-04 - val_loss: 0.0015
# Epoch 7/50
# 6/6 [==============================] - 1s 122ms/step - loss: 6.5174e-05 - val_loss: 0.0044
# Epoch 8/50
# 6/6 [==============================] - 1s 122ms/step - loss: 7.1250e-05 - val_loss: 0.0063
# Epoch 9/50
# 6/6 [==============================] - 1s 122ms/step - loss: 6.7676e-05 - val_loss: 0.0024
# Epoch 10/50
# 6/6 [==============================] - 1s 121ms/step - loss: 4.6946e-05 - val_loss: 0.0013
# Epoch 11/50
# 6/6 [==============================] - 1s 123ms/step - loss: 5.6279e-05 - val_loss: 0.0013
# Epoch 12/50
# 6/6 [==============================] - 1s 132ms/step - loss: 4.9815e-05 - val_loss: 0.0015
# Epoch 13/50
# 6/6 [==============================] - 1s 120ms/step - loss: 4.9946e-05 - val_loss: 0.0023
# Epoch 14/50
# 6/6 [==============================] - 1s 123ms/step - loss: 5.1556e-05 - val_loss: 0.0033
# Epoch 15/50
# 6/6 [==============================] - 1s 123ms/step - loss: 5.3674e-05 - val_loss: 0.0017
# Epoch 16/50
# 6/6 [==============================] - 1s 122ms/step - loss: 5.0416e-05 - val_loss: 0.0020
# Epoch 17/50
# 6/6 [==============================] - 1s 122ms/step - loss: 4.6330e-05 - val_loss: 0.0021
# Epoch 18/50
# 6/6 [==============================] - 1s 122ms/step - loss: 5.1679e-05 - val_loss: 0.0021
# Epoch 19/50
# 6/6 [==============================] - 1s 125ms/step - loss: 4.6318e-05 - val_loss: 0.0026
# Epoch 20/50
# 6/6 [==============================] - 1s 123ms/step - loss: 4.7672e-05 - val_loss: 0.0028
# Epoch 21/50
# 6/6 [==============================] - 1s 122ms/step - loss: 5.3649e-05 - val_loss: 0.0021
# Epoch 22/50
# 6/6 [==============================] - 1s 121ms/step - loss: 5.3635e-05 - val_loss: 0.0027
# Epoch 23/50
# 6/6 [==============================] - 1s 122ms/step - loss: 4.7785e-05 - val_loss: 0.0024
# Epoch 24/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-aa32dbcbd09e> in <module>
#       3     csvdata = dt.CSV_Maker()
#       4     stocklist = ["AAPL", "MSFT", "SBUX", "SNAP", "F"]    #List of Stocks for training
# ----> 5     csvdata.add_csv_data(stocklist)                      #Adds row of data in the csv based on every index
#       6     csvdata.read_csv()
#       7     csvdata.encode_csv()                                     #Shows the row of data encoded since DT cant read strings
#
# D:\Downloads\ComputerScience\Python\AI\TensorFlow\TradingBot\Robinhood\notebooks\DecisionTree.py in add_csv_data(self, stocklist)
#      73             self.make_csv()
#      74             for i in range(len(stocklist)):
# ---> 75                 self.add_csv_row(stocklist[i])
#      76
#      77         def encode_csv(self):
#
# D:\Downloads\ComputerScience\Python\AI\TensorFlow\TradingBot\Robinhood\notebooks\DecisionTree.py in add_csv_row(self, stock)
#      39             sp = spm.Stock_Predict(stock)
#      40             gain, loss = sp.get_gain_loss()
# ---> 41             day_new, day_pred, lst_output = sp.predict_future()
#      42             prediction = self.evaluate_prediction(lst_output)
#      43             buy = 1 if (prediction == 1 and gain == 1) else 0
#
# D:\Downloads\ComputerScience\Python\AI\TensorFlow\TradingBot\Robinhood\notebooks\StockPredictorModule.py in predict_future(self)
#     142         temp_input = list(x_input)
#     143         temp_input = temp_input[0].tolist()
# --> 144         model = self.fit_model()
#     145         lst_output=[]
#     146         n_steps=100
#
# D:\Downloads\ComputerScience\Python\AI\TensorFlow\TradingBot\Robinhood\notebooks\StockPredictorModule.py in fit_model(self)
#      93
#      94         model = self.build_model()
# ---> 95         model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=50, batch_size=64, verbose=1)
#      96         return(model)
#      97
#
# ~\anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\anaconda\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
